# %%
import os
import mlflow
import torch
import random
import numpy as np
from tqdm import tqdm
from os.path import join as pjoin
from datetime import datetime
import sys

PROJECT_PATH = 'C:\\Users\\galiger.gergo\\Desktop\\ecg-denoising\\workspace'
PROJECT_SRC_PATH = os.path.join(PROJECT_PATH, 'src\\refactored')

sys.path.append(PROJECT_SRC_PATH)

from src.trainers.FISTANetTrainer import FISTANetTrainer
from src.utils.loader import DataSplit
from src.models.FISTANetNoConv import FISTANet

RANDOM_SEED = 42

mlflow.set_tracking_uri('http://localhost:8080')

# %%
DATA_DIR = os.path.join(PROJECT_PATH, 'data')
DATA_FILE_GEN = 'generated/BW_master_10000_2024-04-07-12-43-32.pkl'
DATA_FILE_SIGS = 'steinbrinker/testing_data_mvg_avg.npy'
DATA_FILE_BW = 'mit-bih/bw'
DATA_FILE_GAUSS = 'generated/gaussian_noise.npy'
DATA_FILE_BPDN_MAX = 'generated/BW_alphas-BPDN_10000_2024-04-07-12-43-32.npy'
DATA_FILE_BPDN = 'generated/BW_alphas-BPDN-1iters_10000_2024-04-07-12-43-32.npy'
# DATA_FILE_BPDN = 'generated/BW_alphas-BPDN-3iters_10000_2024-04-07-12-43-32.npy'
# DATA_FILE_BPDN = 'generated/BW_alphas-BPDN-5iters_10000_2024-04-07-12-43-32.npy'
DATA_FILE_BPDN_FINAL = 'generated/BW_alphas-BPDN_10000_2024-04-07-12-43-32.npy'
DICT_FILE_BW = 'steinbrinker/dictionary_BW_real_data.npy'
NOISE_TYPE = 'bw'
if NOISE_TYPE == 'bw':
    DATA_FILE_NOISE = DATA_FILE_BW
elif NOISE_TYPE == 'gauss':
    DATA_FILE_NOISE = DATA_FILE_GAUSS
DATA_SIZE = 10000
BATCH_SIZE = 1000
TVT_SPLIT = {
    'train': 80,
    'valid': 10,
    'test': 10
}

FNET_LAYER_NO = 4
FNET_FEATURE_NO = 16
LAMBDA_PRED_SP_LOSS = 1e1
LAMBDA_SYM_LOSS = 1e-3
LAMBDA_SP_LOSS = 1e-2
LOAD_MODEL_RUN = 'bdb03e3d83e94eccbebcaee555cb0da1'
LOAD_MODEL_EPOCH = None

LR_DEC_AFTER = 15000
LR_DEC_EVERY = 10
LEARNING_RATE = 1e-1

# %%
experiment = mlflow.set_experiment('no-conv')

# %%
with mlflow.start_run(log_system_metrics=True) as run:
    # Seed random generators to ensure deterministic experiments
    random.seed(RANDOM_SEED)
    np.random.seed(RANDOM_SEED)
    torch.manual_seed(RANDOM_SEED)
    torch.cuda.manual_seed(RANDOM_SEED)
    torch.cuda.manual_seed_all(RANDOM_SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    generator = torch.Generator()
    generator.manual_seed(RANDOM_SEED) 
    
    # Define PyTorch device
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    # Read and log train, validation and test datasets
    trn_ldr, val_ldr, tst_ldr = DataSplit(DATA_DIR, NOISE_TYPE, DATA_FILE_GEN, DATA_FILE_SIGS, DATA_FILE_NOISE,
                                          DATA_FILE_BPDN, DATA_FILE_BPDN_FINAL, TVT_SPLIT, BATCH_SIZE, generator=generator)
    Psi = torch.from_numpy(np.load(pjoin(DATA_DIR, DICT_FILE_BW)))
    Psi = Psi.clone().detach().to(device=device)
    bpdn_est = np.load(os.path.join(DATA_DIR, DATA_FILE_BPDN_MAX))
    dictionary = np.load(os.path.join(DATA_DIR, DICT_FILE_BW))

    # Load model
    model = FISTANet(FNET_LAYER_NO, FNET_FEATURE_NO).to(device)
    
    # Specify and log training parameters
    dt = datetime.now().strftime('%Y-%m-%d-%H-%M-%S')
    params = {
        'device': device,
        'batch_size': BATCH_SIZE,
        'lr': LEARNING_RATE,
        'lr_dec_after': LR_DEC_AFTER,
        'lr_dec_every': LR_DEC_EVERY,
        'fnet_layer_no': FNET_LAYER_NO,
        'fnet_feature_no': FNET_FEATURE_NO,
        'load_model_run': LOAD_MODEL_RUN,
        'load_model_epoch': LOAD_MODEL_EPOCH,
        'lambda_sp_loss': LAMBDA_SP_LOSS,   
        'lambda_pred_sp_loss': LAMBDA_PRED_SP_LOSS,
        'lambda_sym_loss': LAMBDA_SYM_LOSS,
    }   
    mlflow.log_params(params)

    # Define, train and evaluate model
    trainer = FISTANetTrainer(model, Psi, bpdn_est, dictionary, params)
    trainer.train(trn_ldr, val_ldr, 15000, start_epoch=0, log_model_every=100, log_comp_fig_every=10)
    trainer.evaluate(tst_ldr)
    trainer.evaluate(tst_ldr, criterion=torch.nn.HuberLoss(), crit_text='huber')
# Out:
# Exception in thread 2024/08/03 11:04:55 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\galiger.gergo\.conda\envs\ECGEnvNew\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\galiger.gergo\.conda\envs\ECGEnvNew\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\galiger.gergo\.conda\envs\ECGEnvNew\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\galiger.gergo\.conda\envs\ECGEnvNew\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\galiger.gergo\.conda\envs\ECGEnvNew\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\galiger.gergo\.conda\envs\ECGEnvNew\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\galiger.gergo\.conda\envs\ECGEnvNew\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
#   1%|          | 99/15000 [04:58<12:19:59,  2.98s/it]2024/08/03 11:10:07 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#   1%|▏         | 199/15000 [10:11<12:14:44,  2.98s/it]2024/08/03 11:15:16 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#   2%|▏         | 299/15000 [15:20<12:16:01,  3.00s/it]2024/08/03 11:20:25 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#   3%|▎         | 399/15000 [20:29<12:02:25,  2.97s/it]2024/08/03 11:25:35 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#   3%|▎         | 499/15000 [25:39<12:08:18,  3.01s/it]2024/08/03 11:30:44 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#   4%|▍         | 599/15000 [30:48<11:56:11,  2.98s/it]2024/08/03 11:35:53 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#   5%|▍         | 699/15000 [35:57<11:48:01,  2.97s/it]2024/08/03 11:41:02 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#   5%|▌         | 799/15000 [41:07<11:46:56,  2.99s/it]2024/08/03 11:46:12 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#   6%|▌         | 899/15000 [46:16<11:38:01,  2.97s/it]2024/08/03 11:51:21 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#   7%|▋         | 999/15000 [51:24<11:31:47,  2.96s/it]2024/08/03 11:56:30 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#   7%|▋         | 1099/15000 [56:34<11:30:03,  2.98s/it]2024/08/03 12:01:39 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#   8%|▊         | 1199/15000 [1:01:42<11:29:26,  3.00s/it]2024/08/03 12:06:48 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#   9%|▊         | 1299/15000 [1:06:51<11:18:53,  2.97s/it]2024/08/03 12:11:56 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#   9%|▉         | 1399/15000 [1:11:59<11:13:01,  2.97s/it]2024/08/03 12:17:04 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  10%|▉         | 1499/15000 [1:17:08<11:10:37,  2.98s/it]2024/08/03 12:22:13 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  11%|█         | 1599/15000 [1:22:16<11:05:13,  2.98s/it]2024/08/03 12:27:22 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  11%|█▏        | 1699/15000 [1:27:25<10:57:46,  2.97s/it]2024/08/03 12:32:31 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  12%|█▏        | 1799/15000 [1:32:35<10:55:42,  2.98s/it]2024/08/03 12:37:40 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  13%|█▎        | 1899/15000 [1:37:43<10:46:25,  2.96s/it]2024/08/03 12:42:49 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  13%|█▎        | 1999/15000 [1:42:52<10:50:33,  3.00s/it]2024/08/03 12:47:58 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  14%|█▍        | 2099/15000 [1:48:01<10:42:19,  2.99s/it]2024/08/03 12:53:07 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  15%|█▍        | 2199/15000 [1:53:10<10:36:24,  2.98s/it]2024/08/03 12:58:15 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  15%|█▌        | 2299/15000 [1:58:19<10:28:16,  2.97s/it]2024/08/03 13:03:25 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  16%|█▌        | 2399/15000 [2:03:28<10:21:42,  2.96s/it]2024/08/03 13:08:33 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  17%|█▋        | 2499/15000 [2:08:37<10:17:59,  2.97s/it]2024/08/03 13:13:43 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  17%|█▋        | 2599/15000 [2:13:47<10:17:15,  2.99s/it]2024/08/03 13:18:52 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  18%|█▊        | 2699/15000 [2:18:56<10:13:07,  2.99s/it]2024/08/03 13:24:02 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  19%|█▊        | 2799/15000 [2:24:07<10:07:37,  2.99s/it]2024/08/03 13:29:12 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  19%|█▉        | 2899/15000 [2:29:16<9:58:14,  2.97s/it] 2024/08/03 13:34:22 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  20%|█▉        | 2999/15000 [2:34:25<9:50:26,  2.95s/it] 2024/08/03 13:39:31 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  21%|██        | 3099/15000 [2:39:35<9:51:03,  2.98s/it] 2024/08/03 13:44:40 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  21%|██▏       | 3199/15000 [2:44:44<9:48:19,  2.99s/it] 2024/08/03 13:49:49 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  22%|██▏       | 3299/15000 [2:49:53<9:39:43,  2.97s/it] 2024/08/03 13:54:59 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  23%|██▎       | 3399/15000 [2:55:03<9:36:49,  2.98s/it] 2024/08/03 14:00:08 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  23%|██▎       | 3499/15000 [3:00:12<9:29:05,  2.97s/it] 2024/08/03 14:05:17 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  24%|██▍       | 3599/15000 [3:05:21<9:22:06,  2.96s/it] 2024/08/03 14:10:26 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  25%|██▍       | 3699/15000 [3:10:31<9:20:31,  2.98s/it] 2024/08/03 14:15:36 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  25%|██▌       | 3799/15000 [3:15:41<9:19:09,  3.00s/it] 2024/08/03 14:20:46 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  26%|██▌       | 3899/15000 [3:20:50<9:10:25,  2.97s/it] 2024/08/03 14:25:55 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  27%|██▋       | 3999/15000 [3:26:00<9:07:28,  2.99s/it] 2024/08/03 14:31:05 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  27%|██▋       | 4099/15000 [3:31:09<9:00:10,  2.97s/it] 2024/08/03 14:36:14 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  28%|██▊       | 4199/15000 [3:36:18<8:54:32,  2.97s/it] 2024/08/03 14:41:24 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  29%|██▊       | 4299/15000 [3:41:28<8:50:59,  2.98s/it] 2024/08/03 14:46:33 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  29%|██▉       | 4399/15000 [3:46:38<8:50:33,  3.00s/it] 2024/08/03 14:51:43 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  30%|██▉       | 4499/15000 [3:51:48<8:43:06,  2.99s/it] 2024/08/03 14:56:53 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  31%|███       | 4599/15000 [3:56:57<8:37:52,  2.99s/it] 2024/08/03 15:02:03 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  31%|███▏      | 4699/15000 [4:02:07<8:29:19,  2.97s/it] 2024/08/03 15:07:12 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  32%|███▏      | 4799/15000 [4:07:16<8:25:35,  2.97s/it] 2024/08/03 15:12:21 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  33%|███▎      | 4899/15000 [4:12:25<8:20:55,  2.98s/it] 2024/08/03 15:17:31 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  33%|███▎      | 4999/15000 [4:17:35<8:14:40,  2.97s/it] 2024/08/03 15:22:40 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  34%|███▍      | 5099/15000 [4:22:44<8:15:12,  3.00s/it] 2024/08/03 15:27:49 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  35%|███▍      | 5199/15000 [4:27:54<8:10:31,  3.00s/it] 2024/08/03 15:32:59 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  35%|███▌      | 5299/15000 [4:33:03<7:59:36,  2.97s/it] 2024/08/03 15:38:08 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  36%|███▌      | 5399/15000 [4:38:12<7:54:45,  2.97s/it] 2024/08/03 15:43:17 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  37%|███▋      | 5499/15000 [4:43:21<7:56:08,  3.01s/it] 2024/08/03 15:48:27 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  37%|███▋      | 5599/15000 [4:48:30<7:42:44,  2.95s/it] 2024/08/03 15:53:36 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  38%|███▊      | 5699/15000 [4:53:39<7:42:47,  2.99s/it] 2024/08/03 15:58:45 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  39%|███▊      | 5799/15000 [4:58:49<7:38:37,  2.99s/it] 2024/08/03 16:03:54 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  39%|███▉      | 5899/15000 [5:03:58<7:31:40,  2.98s/it] 2024/08/03 16:09:03 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  40%|███▉      | 5999/15000 [5:09:08<7:24:30,  2.96s/it] 2024/08/03 16:14:13 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  41%|████      | 6099/15000 [5:14:17<7:21:27,  2.98s/it] 2024/08/03 16:19:22 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  41%|████▏     | 6199/15000 [5:19:27<7:20:59,  3.01s/it] 2024/08/03 16:24:32 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  42%|████▏     | 6299/15000 [5:24:36<7:11:59,  2.98s/it] 2024/08/03 16:29:41 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  43%|████▎     | 6399/15000 [5:29:45<7:08:24,  2.99s/it] 2024/08/03 16:34:50 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  43%|████▎     | 6499/15000 [5:34:54<7:00:36,  2.97s/it] 2024/08/03 16:40:00 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  44%|████▍     | 6599/15000 [5:40:04<6:55:34,  2.97s/it] 2024/08/03 16:45:09 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  45%|████▍     | 6699/15000 [5:45:13<6:55:49,  3.01s/it] 2024/08/03 16:50:18 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  45%|████▌     | 6799/15000 [5:50:23<6:46:20,  2.97s/it] 2024/08/03 16:55:28 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  46%|████▌     | 6899/15000 [5:55:32<6:41:50,  2.98s/it] 2024/08/03 17:00:37 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  47%|████▋     | 6999/15000 [6:00:42<6:38:37,  2.99s/it] 2024/08/03 17:05:47 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  47%|████▋     | 7099/15000 [6:05:52<6:31:12,  2.97s/it] 2024/08/03 17:10:58 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  48%|████▊     | 7199/15000 [6:11:02<6:32:40,  3.02s/it] 2024/08/03 17:16:07 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  49%|████▊     | 7299/15000 [6:16:12<6:26:07,  3.01s/it] 2024/08/03 17:21:17 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  49%|████▉     | 7399/15000 [6:21:21<6:19:12,  2.99s/it] 2024/08/03 17:26:26 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  50%|████▉     | 7499/15000 [6:26:30<6:14:02,  2.99s/it]2024/08/03 17:31:35 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  51%|█████     | 7599/15000 [6:31:39<6:07:11,  2.98s/it]2024/08/03 17:36:44 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  51%|█████▏    | 7699/15000 [6:36:48<6:00:06,  2.96s/it]2024/08/03 17:41:54 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  52%|█████▏    | 7799/15000 [6:41:57<5:56:52,  2.97s/it]2024/08/03 17:47:03 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  53%|█████▎    | 7899/15000 [6:47:07<5:51:58,  2.97s/it]2024/08/03 17:52:13 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  53%|█████▎    | 7999/15000 [6:52:17<5:49:32,  3.00s/it]2024/08/03 17:57:22 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  54%|█████▍    | 8099/15000 [6:57:27<5:45:35,  3.00s/it]2024/08/03 18:02:32 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  55%|█████▍    | 8199/15000 [7:02:36<5:38:15,  2.98s/it]2024/08/03 18:07:41 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  55%|█████▌    | 8299/15000 [7:07:45<5:32:47,  2.98s/it]2024/08/03 18:12:50 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  56%|█████▌    | 8399/15000 [7:12:54<5:26:53,  2.97s/it]2024/08/03 18:17:59 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  57%|█████▋    | 8499/15000 [7:18:03<5:22:20,  2.98s/it]2024/08/03 18:23:09 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  57%|█████▋    | 8599/15000 [7:23:13<5:16:09,  2.96s/it]2024/08/03 18:28:18 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  58%|█████▊    | 8699/15000 [7:28:23<5:12:12,  2.97s/it]2024/08/03 18:33:28 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  59%|█████▊    | 8799/15000 [7:33:33<5:11:32,  3.01s/it]2024/08/03 18:38:38 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  59%|█████▉    | 8899/15000 [7:38:43<5:04:42,  3.00s/it]2024/08/03 18:43:48 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  60%|█████▉    | 8999/15000 [7:43:53<4:58:57,  2.99s/it]2024/08/03 18:48:58 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  61%|██████    | 9099/15000 [7:49:02<4:53:28,  2.98s/it]2024/08/03 18:54:07 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  61%|██████▏   | 9199/15000 [7:54:11<4:46:48,  2.97s/it]2024/08/03 18:59:16 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  62%|██████▏   | 9299/15000 [7:59:21<4:45:31,  3.00s/it]2024/08/03 19:04:26 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  63%|██████▎   | 9399/15000 [8:04:30<4:36:43,  2.96s/it]2024/08/03 19:09:35 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  63%|██████▎   | 9499/15000 [8:09:39<4:32:18,  2.97s/it]2024/08/03 19:14:44 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  64%|██████▍   | 9599/15000 [8:14:48<4:31:47,  3.02s/it]2024/08/03 19:19:54 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  65%|██████▍   | 9699/15000 [8:19:58<4:24:31,  2.99s/it]2024/08/03 19:25:03 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  65%|██████▌   | 9799/15000 [8:25:08<4:18:28,  2.98s/it]2024/08/03 19:30:14 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  66%|██████▌   | 9899/15000 [8:30:19<4:14:05,  2.99s/it]2024/08/03 19:35:24 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  67%|██████▋   | 9999/15000 [8:35:28<4:07:48,  2.97s/it]2024/08/03 19:40:34 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  67%|██████▋   | 10099/15000 [8:40:38<4:02:16,  2.97s/it]2024/08/03 19:45:43 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  68%|██████▊   | 10199/15000 [8:45:48<3:58:23,  2.98s/it]2024/08/03 19:50:53 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  69%|██████▊   | 10299/15000 [8:50:57<3:52:24,  2.97s/it]2024/08/03 19:56:02 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  69%|██████▉   | 10399/15000 [8:56:06<3:48:02,  2.97s/it]2024/08/03 20:01:12 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  70%|██████▉   | 10499/15000 [9:01:16<3:46:18,  3.02s/it]2024/08/03 20:06:21 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  71%|███████   | 10599/15000 [9:06:26<3:38:44,  2.98s/it]2024/08/03 20:11:31 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  71%|███████▏  | 10699/15000 [9:11:35<3:34:59,  3.00s/it]2024/08/03 20:16:41 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  72%|███████▏  | 10799/15000 [9:16:45<3:29:12,  2.99s/it]2024/08/03 20:21:50 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  73%|███████▎  | 10899/15000 [9:21:54<3:23:28,  2.98s/it]2024/08/03 20:27:00 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  73%|███████▎  | 10999/15000 [9:27:04<3:18:42,  2.98s/it]2024/08/03 20:32:10 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  74%|███████▍  | 11099/15000 [9:32:14<3:13:06,  2.97s/it]2024/08/03 20:37:19 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  75%|███████▍  | 11199/15000 [9:37:23<3:07:39,  2.96s/it]2024/08/03 20:42:28 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  75%|███████▌  | 11299/15000 [9:42:33<3:05:32,  3.01s/it]2024/08/03 20:47:38 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  76%|███████▌  | 11399/15000 [9:47:44<2:59:52,  3.00s/it]2024/08/03 20:52:52 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  77%|███████▋  | 11499/15000 [9:52:56<2:53:38,  2.98s/it]2024/08/03 20:58:01 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  77%|███████▋  | 11599/15000 [9:58:06<2:48:37,  2.98s/it]2024/08/03 21:03:11 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  78%|███████▊  | 11699/15000 [10:03:15<2:43:37,  2.97s/it]2024/08/03 21:08:21 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  79%|███████▊  | 11799/15000 [10:08:25<2:39:13,  2.98s/it]2024/08/03 21:13:31 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  79%|███████▉  | 11899/15000 [10:13:35<2:33:27,  2.97s/it]2024/08/03 21:18:40 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  80%|███████▉  | 11999/15000 [10:18:44<2:28:05,  2.96s/it]2024/08/03 21:23:50 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  81%|████████  | 12099/15000 [10:23:54<2:24:42,  2.99s/it]2024/08/03 21:28:59 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  81%|████████▏ | 12199/15000 [10:29:03<2:19:00,  2.98s/it]2024/08/03 21:34:08 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  82%|████████▏ | 12299/15000 [10:34:11<2:13:34,  2.97s/it]2024/08/03 21:39:17 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  83%|████████▎ | 12399/15000 [10:39:20<2:08:17,  2.96s/it]2024/08/03 21:44:26 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  83%|████████▎ | 12499/15000 [10:44:30<2:03:57,  2.97s/it]2024/08/03 21:49:35 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  84%|████████▍ | 12599/15000 [10:49:39<1:58:40,  2.97s/it]2024/08/03 21:54:44 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  85%|████████▍ | 12699/15000 [10:54:48<1:53:23,  2.96s/it]2024/08/03 21:59:54 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  85%|████████▌ | 12799/15000 [10:59:58<1:49:10,  2.98s/it]2024/08/03 22:05:04 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  86%|████████▌ | 12899/15000 [11:05:08<1:44:41,  2.99s/it]2024/08/03 22:10:13 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  87%|████████▋ | 12999/15000 [11:10:17<1:39:13,  2.98s/it]2024/08/03 22:15:22 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  87%|████████▋ | 13099/15000 [11:15:27<1:34:26,  2.98s/it]2024/08/03 22:20:32 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  88%|████████▊ | 13199/15000 [11:20:36<1:28:58,  2.96s/it]2024/08/03 22:25:41 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  89%|████████▊ | 13299/15000 [11:25:45<1:23:53,  2.96s/it]2024/08/03 22:30:50 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  89%|████████▉ | 13399/15000 [11:30:55<1:19:21,  2.97s/it]2024/08/03 22:36:00 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  90%|████████▉ | 13499/15000 [11:36:05<1:14:04,  2.96s/it]2024/08/03 22:41:10 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  91%|█████████ | 13599/15000 [11:41:14<1:09:04,  2.96s/it]2024/08/03 22:46:19 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  91%|█████████▏| 13699/15000 [11:46:24<1:05:10,  3.01s/it]2024/08/03 22:51:29 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  92%|█████████▏| 13799/15000 [11:51:33<59:37,  2.98s/it]  2024/08/03 22:56:39 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  93%|█████████▎| 13899/15000 [11:56:44<55:03,  3.00s/it]  2024/08/03 23:01:49 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  93%|█████████▎| 13999/15000 [12:01:53<49:34,  2.97s/it]  2024/08/03 23:06:59 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  94%|█████████▍| 14099/15000 [12:07:03<44:36,  2.97s/it]  2024/08/03 23:12:09 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  95%|█████████▍| 14199/15000 [12:12:13<39:45,  2.98s/it]  2024/08/03 23:17:18 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  95%|█████████▌| 14299/15000 [12:17:23<34:43,  2.97s/it]  2024/08/03 23:22:29 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  96%|█████████▌| 14399/15000 [12:22:33<29:47,  2.97s/it]2024/08/03 23:27:39 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  97%|█████████▋| 14499/15000 [12:27:43<24:57,  2.99s/it]2024/08/03 23:32:48 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  97%|█████████▋| 14599/15000 [12:32:52<19:52,  2.97s/it]2024/08/03 23:37:58 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  98%|█████████▊| 14699/15000 [12:38:02<14:55,  2.97s/it]2024/08/03 23:43:07 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  99%|█████████▊| 14799/15000 [12:43:11<09:59,  2.98s/it]2024/08/03 23:48:16 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
#  99%|█████████▉| 14899/15000 [12:48:20<04:59,  2.97s/it]2024/08/03 23:53:26 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 100%|█████████▉| 14999/15000 [12:53:30<00:02,  2.96s/it]2024/08/03 23:58:35 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 100%|██████████| 15000/15000 [12:53:39<00:00,  3.09s/it]
# 2024/08/03 23:58:37 INFO mlflow.tracking._tracking_service.client: 🏃 View run mysterious-zebra-846 at: http://localhost:8080/#/experiments/433992469522655304/runs/2c2db1f4c98141e485b98a57c4f2ee79.
# 2024/08/03 23:58:37 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:8080/#/experiments/433992469522655304.
# 2024/08/03 23:58:37 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/08/03 23:58:37 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
